# %%
import fiona 
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_file("C:/Users/tamar/Desktop/bikeways-wgs84-latitude-longitude/CENTRELINE_BIKEWAY_OD_WGS84.shp")

# %%
len(gdf)
# Out:
# 69378

# %%
pd.options.display.max_columns = 100

# %%
gdf.head()
# Out:
#      GEO_ID  LFN_ID                LF_NAME ADDRESS_L ADDRESS_R OE_FLAG_L  \
# 0  30079678   19155         Waterfront Trl      None      None         N
# 1  30079680   19166  Marie Curtis Park Trl      None      None         N
# 2  30079677   19155         Waterfront Trl      None      None         N
# 3  30082310   10685              Island Rd      None      None         N
# 4  30008940   19155         Waterfront Trl      None      None         N
#
#   OE_FLAG_R  LONUML  HINUML  LONUMR  HINUMR     FNODE     TNODE  ONE_WAY_DI  \
# 0         N       0       0       0       0  30079676  30079656           0
# 1         N       0       0       0       0  30079676  30079679           0
# 2         N       0       0       0       0  30008708  30079676           0
# 3         N       0       0       0       0  30008708  30082309           0
# 4         N       0       0       0       0  30008711  30008708           0
#
#     DIR_CODE_D   FCODE FCODE_DESC       JURIS_CODE  OBJECTID  \
# ...

# %%
gdf.plot();

# %%
# all based in shapely
# shapely is the package to look at for geometry
# spatial join - join on geometry not label

# %%
dir(gdf.geometry.iloc[0])
# Out:
# ['__and__',
#  '__array_interface__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__geom__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__p__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '__xor__',
#  '_crs',
#  '_ctypes_data',
#  '_geom',
#  '_get_coords',
#  '_is_empty',
#  '_lgeos',
#  '_ndim',
#  '_other_owned',
#  '_repr_svg_',
#  '_set_coords',
#  'almost_equals',
#  'area',
#  'array_interface',
#  'array_interface_base',
#  'boundary',
#  'bounds',
#  'buffer',
#  'centroid',
#  'contains',
#  'convex_hull',
#  'coords',
#  'covers',
#  'crosses',
#  'ctypes',
#  'difference',
#  'disjoint',
# ...
